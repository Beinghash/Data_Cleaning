# %% [markdown]
# ---
#
#
#
#
#
#
# # Missing Data

# %% [markdown]
# What does "missing data" mean? What is a missing value? It depends on the origin of the data and the context it was generated. For example, for a survey, a `Salary` field with an empty value, or a number 0, or an invalid value (a string for example) can be considered "missing data". These concepts are related to the values that Python will consider "Falsy":

# %%
import numpy as np
import pandas as pd

# %%
falsy_values = (0 ,False, None, '', [], {})

# %% [markdown]
# For Python, all the values above are considered "falsy":

# %%
any(falsy_values)
# Out:
# False

# %% [markdown]
# Numpy has a special "nullable" value for numbers which is `np.nan`. It's *NaN*: "Not a number"

# %%
np.nan
# Out:
# nan

# %% [markdown]
# The `np.nan` value is kind of a virus. Everything that it touches becomes np.nan:

# %%
3  + np.nan
# Out:
# nan

# %%
3 * np.nan
# Out:
# nan

# %% [markdown]
# As we said, `np.nan` is like a virus. If you have any `nan` value in an array and you try to perform an operation on it, you'll get unexpected results:

# %%
a = np.array([1,2,3,4,np.nan,np.nan,5])
a
# Out:
# array([ 1.,  2.,  3.,  4., nan, nan,  5.])

# %%
a.sum().item()                                      # Adding ".item()" to avoid getting the data type along with the value
# Out:
# nan

# %%
a.mean()
# Out:
# np.float64(nan)

# %% [markdown]
# Numpy also supports an "Infinite" type:

# %%
np.inf
# Out:
# inf

# %% [markdown]
# Which also behaves as a virus:

# %%
3 + np.inf
# Out:
# inf

# %%
np.inf / 3
# Out:
# inf

# %%
np.inf / np.inf
# Out:
# nan

# %% [markdown]
# For a numeric array, the `None` value is replaced by `np.nan`:

# %%
a = np.array([1,2,3,4,np.nan,np.nan,None,5], dtype=np.float128)
a
# Out:
# array([ 1.,  2.,  3.,  4., nan, nan, nan,  5.], dtype=float128)

# %%
b = np.array([1,2,3,4,np.nan,np.inf,5], dtype=np.float128)
b
# Out:
# array([ 1.,  2.,  3.,  4., nan, inf,  5.], dtype=float128)

# %%
b.sum()
# Out:
# np.longdouble('nan')

# %% [markdown]
# # Checking for `nan` or `inf`
#
# There are two functions: `np.isnan` and `np.isinf` that will perform the desired checks:

# %%
np.isnan(np.nan).item()
# Out:
# True

# %%
np.isinf(np.inf).item()
# Out:
# True

# %% [markdown]
# And the joint operation can be performed with `np.isfinite`.

# %%
np.isfinite(np.nan), np.isfinite(np.inf)
# Out:
# (np.False_, np.False_)

# %% [markdown]
# `np.isnan` and `np.isinf` also take arrays as inputs, and return boolean arrays as results:

# %%
np.isnan(np.array([1,2,3,np.nan,np.inf,5], dtype=np.float128))
# Out:
# array([False, False, False,  True, False, False])

# %%
np.isinf(np.array([1,2,3,4,np.nan,np.inf,5], dtype=np.float128))
# Out:
# array([False, False, False, False, False,  True, False])

# %%
np.isfinite(np.array([1,2,3,np.nan,np.inf,5], dtype=np.float128))
# Out:
# array([ True,  True,  True, False, False,  True])

# %% [markdown]
# Note: It's not so common to find infinite values. From now on, we'll keep working with only `np.nan`

# %% [markdown]
# ---
#
#
# # Filtering them out
# Whenever you're trying to perform an operation with a `Numpy` array and you know there might be missing values, you'll need to filter them out before proceeding, to avoid ` nan` propagation. We'll use a combination of the previous `np.isnan` + boolean arrays for this purpose:

# %%
a = np.array([1, 2, 3, np.nan, np.nan, 4])

# %%
a[~np.isnan(a)]
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# Which is equivalent to:

# %%
a[np.isfinite(a)]
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# And with that result, all the operation can be now performed:

# %%
a[np.isfinite(a)].sum().item()
# Out:
# 10.0

# %%
a[np.isfinite(a)].mean().item()
# Out:
# 2.5

# %% [markdown]
# ---
